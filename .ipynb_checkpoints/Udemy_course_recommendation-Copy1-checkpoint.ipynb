# %% [markdown]
# # Udemy_Course_Recommendation

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('udemy_courses.csv.xls')

# %%
data
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %%
data.describe()
# Out:
#           course_id        price  num_subscribers   num_reviews  num_lectures  \
# count  3.678000e+03  3678.000000      3678.000000   3678.000000   3678.000000
# mean   6.759720e+05    66.049483      3197.150625    156.259108     40.108755
# std    3.432732e+05    61.005755      9504.117010    935.452044     50.383346
# min    8.324000e+03     0.000000         0.000000      0.000000      0.000000
# 25%    4.076925e+05    20.000000       111.000000      4.000000     15.000000
# 50%    6.879170e+05    45.000000       911.500000     18.000000     25.000000
# 75%    9.613555e+05    95.000000      2546.000000     67.000000     45.750000
# max    1.282064e+06   200.000000    268923.000000  27445.000000    779.000000
#
#        content_duration
# count       3678.000000
# mean           4.094517
# std            6.053840
# min            0.000000
# 25%            1.000000
# 50%            2.000000
# 75%            4.500000
# max           78.500000

# %%
for i in data.columns:
    print(i,':',data[i].nunique())
# Out:
# course_id : 3672
# course_title : 3663
# url : 3672
# is_paid : 2
# price : 38
# num_subscribers : 2197
# num_reviews : 511
# num_lectures : 229
# level : 4
# content_duration : 105
# published_timestamp : 3672
# subject : 4

# %%
data.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %% [markdown]
# * Cleaned data

# %%
# Checking duplicate values

# %%
duplicate_rows = data[data.duplicated()]

# %%
duplicate_rows
# Out:
#       course_id                                       course_title  \
# 787      837322  Essentials of money value: Get a financial Life !
# 788     1157298  Introduction to Forex Trading Business For Beg...
# 894     1035638                 Understanding Financial Statements
# 1100    1084454                  CFA Level 2- Quantitative Methods
# 1473     185526                             MicroStation - Células
# 2561      28295  Learn Web Designing & HTML5/CSS3 Essentials in...
#
#                                                     url  is_paid  price  \
# 787    https://www.udemy.com/essentials-of-money-value/     True     20
# 788   https://www.udemy.com/introduction-to-forex-tr...     True     20
# 894   https://www.udemy.com/understanding-financial-...     True     25
# 1100  https://www.udemy.com/cfa-level-2-quantitative...     True     40
# 1473        https://www.udemy.com/microstation-celulas/     True     20
# ...

# %%
data1=data.copy()

# %%
data1
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
# Droping duplicate values

# %%
data1=data1.drop_duplicates()

# %%
data1
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
# convert published_timestamp in to dattime format
data1['published_timestamp'] = pd.to_datetime(data1['published_timestamp'])

# %%
# Extract year, month, day, etc. from the 'published_timestamp' column
# data1['year'] = data1['published_timestamp'].dt.year
# data1['month'] = data1['published_timestamp'].dt.month
# data1['day'] = data1['published_timestamp'].dt.day

# %%
# Exploratory Data Analysis

# %%
sns.countplot(x='is_paid',data=data1)
plt.title('Distribution of Paid and Unpaid Courses')
plt.plot()
# Out:
# []

# %% [markdown]
# * Paided courses are more compair to unpaid

# %%
data1['level'].value_counts().plot.pie(explode=(0,0,0,0.1),shadow=True,autopct='%1.2f%%')
plt.title('Distribution of Levels')
plt.show()

# %%
data1.corr()
# Out:
#                   course_id   is_paid     price  num_subscribers  num_reviews  \
# course_id          1.000000 -0.013765  0.143062        -0.166094    -0.058310
# is_paid           -0.013765  1.000000  0.328910        -0.267056    -0.087445
# price              0.143062  0.328910  1.000000         0.050436     0.113568
# num_subscribers   -0.166094 -0.267056  0.050436         1.000000     0.651070
# num_reviews       -0.058310 -0.087445  0.113568         0.651070     1.000000
# num_lectures      -0.024735  0.112788  0.329944         0.158351     0.243019
# content_duration  -0.057236  0.094594  0.293200         0.162118     0.228852
#
#                   num_lectures  content_duration
# course_id            -0.024735         -0.057236
# is_paid               0.112788          0.094594
# price                 0.329944          0.293200
# num_subscribers       0.158351          0.162118
# num_reviews           0.243019          0.228852
# ...

# %%
data1.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
# One-hot encoding for 'level' feature
data1 = pd.get_dummies(data1, columns=['level'])
data1
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
data1.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'content_duration',
#        'published_timestamp', 'subject', 'level_All Levels',
#        'level_Beginner Level', 'level_Expert Level',
#        'level_Intermediate Level'],
#       dtype='object')

# %%
data1['subject'].unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)

# %%
def search_courses_by_subject(data1, subject):
    # Filter dataset based on subject
    filtered_df = data1[data1['subject'] == subject]

    # Extract relevant columns
    results = filtered_df[['course_title', 'url', 'price','num_subscribers']]

    return results

# %%
search_courses_by_subject(data1,'Web Development')
# Out:
#                                            course_title  \
# 2478  Learn Web Designing & HTML5/CSS3 Essentials in...
# 2479  Learning Dynamic Website Design - PHP MySQL an...
# 2480  ChatBots: Messenger ChatBot with API.AI and No...
# 2481                                  Projects in HTML5
# 2482  Programming Foundations: HTML5 + CSS3 for Entr...
# ...                                                 ...
# 3673  Learn jQuery from Scratch - Master of JavaScri...
# 3674  How To Design A WordPress Website With No Codi...
# 3675                      Learn and Build using Polymer
# 3676  CSS Animations: Create Amazing Effects on Your...
# 3677  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  price  \
# 2478  https://www.udemy.com/build-beautiful-html5-we...     75
# 2479  https://www.udemy.com/learning-dynamic-website...     50
# 2480                    https://www.udemy.com/chatbots/     50
# ...
